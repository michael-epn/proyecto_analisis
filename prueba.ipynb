# %%
import pandas as pd
import sqlite3 as sql

dataset_1 = pd.read_csv("panaderia_productos.csv")
dataset_2 = pd.read_json("panaderia_productos.json")
dataset_3 = pd.read_xml("panaderia_productos.xml")
conn = sql.connect("panaderia_productos.db")
dataset_4 = pd.read_sql_query("SELECT * FROM productos_sucios", conn)
conn.close()

print("\n//////// PANADERIA_PRODUCTOS.CSV //////////////")
print(dataset_1)
print("\n//////// PANADERIA_PRODUCTOS.JSON /////////////")
print(dataset_2)
print("\n//////// PANADERIA_PRODUCTOS.XML //////////////")
print(dataset_3)
print("\n//////// PANADERIA_PRODUCTOS.DB ///////////////")
print(dataset_4)
# Out:
# //////// PANADERIA_PRODUCTOS.CSV //////////////
#     id               nombre precio_compra   categoria stock proveedor  \
# 0    1               Gusano         15.34     Insumos   234  DelyClar
# 1    2               Gusano         10.05   Cafetería     0      Vita
# 2    3               Gusano          9.11     Insumos   177  DelyClar
# 3    4  Pastel de Chocolate         17.33   Panadería   116      Vita
# 4    5               Gusano         14.64     Insumos    11      Vita
# ..  ..                  ...           ...         ...   ...       ...
# 94  95                Cacho         19.73     Insumos   NaN  DelyClar
# 95  96    Pan de Masa Madre          3.99   Cafetería   231      Vita
# 96  97               Gusano         15.86   Panadería   236   Moderna
# 97  98               Gusano         10.78  Pastelería   274   Moderna
# 98  99               Gusano          9.84  Pastelería     2  DelyClar
#
#    precio_venta_publico
# 0                 23.01
# 1                 15.08
# 2                 13.66
# 3                 25.99
# 4                 21.96
# ..                  ...
# 94                29.59
# 95                 5.99
# 96                23.79
# 97                16.17
# 98                14.76
#
# [99 rows x 7 columns]
#
# //////// PANADERIA_PRODUCTOS.JSON /////////////
#      id               nombre precio_compra   categoria stock proveedor  \
# 0   100               Gusano          3.99  Pastelería   186   Moderna
# 1   101         Pan de Leche         16.69   Panadería   199  DelyClar
# 2   102    Pan de Masa Madre         12.07   Panadería    70      Vita
# 3   103                Donas          8.69   Cafetería   136   Moderna
# 4   104                Donas          2.67   Panadería   293   Moderna
# ..  ...                  ...           ...         ...   ...       ...
# 95  195  Pastel de Chocolate         16.37  Pastelería   212  DelyClar
# 96  196         Pan de Leche         18.63                66      Vita
# 97  197                Cacho         texto     Insumos    86      Vita
# 98  198    Pan de Masa Madre          3.48  Pastelería    28      Vita
# 99  199               Gusano          13.3   Panadería    96   Moderna
#
#    precio_venta_publico
# 0                  5.99
# 1                 25.04
# 2                 18.11
# 3                 13.04
# 4                   4.0
# ..                  ...
# 95                24.55
# 96                27.95
# 97                 9.82
# 98                texto
# 99                19.95
#
# [100 rows x 7 columns]
#
# //////// PANADERIA_PRODUCTOS.XML //////////////
#      id             nombre precio_compra   categoria stock proveedor  \
# 0   200              Cacho          5.42  Pastelería   155      Vita
# 1   201              Cacho          8.72  Pastelería   205   Moderna
# 2   202       Pan de Leche          10.2  Pastelería   262  DelyClar
# 3   203              Donas         15.34   Cafetería   137      Vita
# 4   204           Galletas         texto  Pastelería    55      Vita
# ..  ...                ...           ...         ...   ...       ...
# 95  295  Pan de Masa Madre          18.6   Panadería   130  DelyClar
# 96  296       Pan de Leche         12.92   Cafetería    87  DelyClar
# 97  297           Galletas         error     Insumos    29  DelyClar
# 98  298             Gusano          1.99        None    96  DelyClar
# 99  299           Galletas         18.34     Insumos   291   Moderna
#
#    precio_venta_publico
# 0                 error
# 1                 13.08
# 2                  15.3
# 3                 23.01
# 4                  2.92
# ..                  ...
# 95                 27.9
# 96                19.38
# 97                12.16
# 98                 2.98
# 99                27.51
#
# [100 rows x 7 columns]
#
# //////// PANADERIA_PRODUCTOS.DB ///////////////
#      id             nombre precio_compra   categoria stock proveedor  \
# 0   300             Gusano          11.5       texto    44      Vita
# 1   301                N/A          12.4   Cafetería   267   Moderna
# 2   302  Pan de Masa Madre          6.86  Pastelería   195  DelyClar
# 3   303       Pan de Leche         14.11   Cafetería    77  DelyClar
# 4   304  Pan de Masa Madre          1.45   Panadería   177   Moderna
# ..  ...                ...           ...         ...   ...       ...
# 95  395  Pan de Masa Madre          8.84     Insumos    40      Vita
# 96  396  Pan de Masa Madre         10.93   Panadería    67   Moderna
# 97  397              Cacho         18.51   Panadería   158      Vita
# 98  398       Pan de Leche          2.77         NaN   189  DelyClar
# 99  399              Donas         14.89       error   292  DelyClar
#
#    precio_venta_publico
# 0                 17.25
# 1                  18.6
# 2                 10.29
# 3                 21.16
# 4                 texto
# ..                  ...
# 95                13.26
# 96                16.39
# 97                27.77
# 98                 4.16
# 99                22.34
#
# [100 rows x 7 columns]

# %%
print("/////////// DATAFRAMES CONCATENADOS ///////////////")
dataset = pd.concat([dataset_1,dataset_2,dataset_3,dataset_4], ignore_index=True)
print(" \n- Mostrar las primeras 10 filas y los tipos de datos de cada columna")
print(dataset.head(10))
print(dataset.info())
# Out:
# /////////// DATASETS CONCATENADOS ///////////////
#
# - Mostrar las primeras 10 filas y los tipos de datos de cada columna
#    id               nombre precio_compra   categoria stock proveedor  \
# 0   1               Gusano         15.34     Insumos   234  DelyClar
# 1   2               Gusano         10.05   Cafetería     0      Vita
# 2   3               Gusano          9.11     Insumos   177  DelyClar
# 3   4  Pastel de Chocolate         17.33   Panadería   116      Vita
# 4   5               Gusano         14.64     Insumos    11      Vita
# 5   6         Pan de Leche          9.63   Panadería   118   Moderna
# 6   7                  NaN         15.85  Pastelería   143  DelyClar
# 7   8    Pan de Masa Madre          9.72   Panadería    94   Moderna
# 8   9  Pastel de Chocolate         15.92  Pastelería   101   Moderna
# 9  10         Pan de Leche          5.74   Cafetería   158  DelyClar
#
#   precio_venta_publico
# 0                23.01
# 1                15.08
# 2                13.66
# 3                25.99
# 4                21.96
# 5                  NaN
# 6                23.77
# 7                14.58
# 8                23.88
# 9                 8.61
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 399 entries, 0 to 398
# Data columns (total 7 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    399 non-null    int64
#  1   nombre                393 non-null    object
#  2   precio_compra         395 non-null    object
#  3   categoria             393 non-null    object
#  4   stock                 396 non-null    object
#  5   proveedor             394 non-null    object
#  6   precio_venta_publico  394 non-null    object
# dtypes: int64(1), object(6)
# memory usage: 21.9+ KB
# None

# %%
print("\n////////////// IDENTIFICANDO VALORES NULOS, VACIOS O INCORRECTOS ///////////////////")
print(dataset.isnull().sum())

print("\n############ CALCULANDO EL PORCENTAJE DE DATOS SUCIOS EN CADA COLUMNA ###########")
total = len(dataset)
nulos = dataset.isnull().sum()
porcentaje = (nulos / total) * 100
print(porcentaje.round(2).astype(str) + " %")
# Out:
# ////////////// IDENTIFICANDO VALORES NULOS, VACIOS O INCORRECTOS ///////////////////
# id                      0
# nombre                  6
# precio_compra           4
# categoria               6
# stock                   3
# proveedor               5
# precio_venta_publico    5
# dtype: int64
#
# ############ CALCULANDO EL PORCENTAJE DE DATOS SUCIOS EN CADA COLUMNA ###########
# id                       0.0 %
# nombre                   1.5 %
# precio_compra            1.0 %
# categoria                1.5 %
# stock                   0.75 %
# proveedor               1.25 %
# precio_venta_publico    1.25 %
# dtype: object

# %%
print("///////////// IDENTIFICANDO DUPLICADOS ////////////////")
print(dataset.duplicated().sum())
print("//////////// VALORES FUERA DE DOMINIO //////////////////")
print(dataset["stock"].unique())
print("//////////// STRING SUCIOS //////////////////////")
print(dataset["categoria"].str.contains(" ",regex = False).sum())
# Out:
# ///////////// IDENTIFICANDO DUPLICADOS ////////////////
# 0
# //////////// VALORES FUERA DE DOMINIO //////////////////
# ['234' '0' '177' '116' '11' '118' '143' '94' '101' '158' 'error' '73'
#  '231' '16' '127' '199' '100' '17' '274' '98' '259' '283' '296' '72' '155'
#  '227' '157' '26' '1' '27' '193' '219' '77' '53' '134' '8' '270' '37' '61'
#  '86' '220' '15' '114' '170' '176' '298' '67' '78' '208' '190' '201' nan
#  '151' '276' '242' '223' '111' '213' '146' '46' '3' '12' '4' '185' '41'
#  '290' '103' '250' '288' '81' '293' '299' '52' '121' '65' '137' '92' '63'
#  '254' '243' '171' '136' '215' '141' '262' '175' '236' '2' '186' '70' '40'
#  '34' '125' '51' '289' '126' '180' '279' '29' '14' '263' '251' '23' '83'
#  '96' '49' '56' '' '248' '285' '113' '152' '32' '197' '297' '240' '204'
#  '209' '60' '228' '239' '255' '91' '147' 'NaN' '28' '117' '205' '264'
#  '133' '75' '162' '10' '271' '55' '148' '13' '44' '212' '230' '108' '246'
#  '214' 'N/A' '218' '238' '174' '66' '222' '7' '256' '166' '149' '206'
#  '128' '138' '69' '145' '129' '179' '275' '202' '226' '261' '272' '93'
#  'texto' '95' '135' '6' '5' '194' '64' '109' '294' '119' '50' '267' '181'
#  '107' '36' '282' '130' '87' '291' '195' '286' '22' '192' '88' '59' '183'
#  '154' '45' '221' '178' '252' '38' '229' '30' '277' '184' '191' '235' '79'
#  '287' '216' '244' '142' '33' '54' '144' '112' '110' '25' '102' '189'
#  '292']
# //////////// STRING SUCIOS //////////////////////
# 0
